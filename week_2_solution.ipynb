# %% [markdown]
# <a href="https://colab.research.google.com/github/gokhanturer/Data_science_notebooks/blob/main/week_2_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CLARUSWAY_UNDER-MIDDLE-SCALE_1917x399.png](attachment:CLARUSWAY_UNDER-MIDDLE-SCALE_1917x399.png)

# %% [markdown]
# # Weekly Agenda

# %% [markdown]
# ## Question-1

# %%
import pandas as pd
import numpy as np
from scipy import stats
import re

# to avoid warnings
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %% [markdown]
# #### **1.	Read the dataset as a dataframe via dataset link. Create a copy of your dataframe. Solve the rest of the questions using this dataframe copy.**
#
# #### **1. Veri kümesi bağlantısı aracılığıyla veri kümesini veri çerçevesi olarak okuyun. Veri çerçevenizin bir kopyasını oluşturun. Bu veri çerçevesi kopyasını kullanarak kalan soruları çözün.**

# %%
data = pd.read_csv("weatherAUS.csv")
df= data.copy()
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# #### 2.	Find out the describe and info attributes of the dataframe.
# #### 2.	Veri çerçevesinin açıklama ve bilgi özelliklerini öğrenin.
#
# temps min = bazen sadece en yakın tam dereceye kadar bilinir
# evaporation = buharlaşma
# maxwindgustdirn = 24 saatten gece yarısına kadar en kuvvetli rüzgarın yönü
# maxwindgustspd = 24 saatten gece yarısına kadar en kuvvetli rüzgarın hızı
# maxwindgusttime = en güçlü rüzgar esintisi zamanı

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# #### 3.	Find out the shape and size info of the dataset.

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-600bcb0c72f9> in <module>
# ----> 1 df.size
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### 4.	Find out the types values of the columns and save the result as a dataframe.

# %%
dtypes = pd.DataFrame(df.dtypes, columns=['dtypes'])
dtypes
# Out:
#                 dtypes
# Date            object
# Location        object
# MinTemp        float64
# MaxTemp        float64
# Rainfall       float64
# Evaporation    float64
# Sunshine       float64
# WindGustDir     object
# WindGustSpeed  float64
# WindDir9am      object
# WindDir3pm      object
# WindSpeed9am   float64
# WindSpeed3pm   float64
# Humidity9am    float64
# Humidity3pm    float64
# Pressure9am    float64
# Pressure3pm    float64
# Cloud9am       float64
# Cloud3pm       float64
# Temp9am        float64
# Temp3pm        float64
# RainToday       object
# RainTomorrow    object

# %% [markdown]
# #### 5.	Find out the non-null counts of the columns and save the result as a dataframe.

# %%
notnull = pd.DataFrame(df.notnull().sum(), columns=['notnull'])
notnull
# Out:
#                notnull
# Date            145460
# Location        145460
# MinTemp         143975
# MaxTemp         144199
# Rainfall        142199
# Evaporation      82670
# Sunshine         75625
# WindGustDir     135134
# WindGustSpeed   135197
# WindDir9am      134894
# WindDir3pm      141232
# WindSpeed9am    143693
# WindSpeed3pm    142398
# Humidity9am     142806
# Humidity3pm     140953
# Pressure9am     130395
# Pressure3pm     130432
# Cloud9am         89572
# Cloud3pm         86102
# Temp9am         143693
# Temp3pm         141851
# RainToday       142199
# RainTomorrow    142193

# %% [markdown]
# #### 6.	Find out the null counts of the columns and save the result as a dataframe.

# %%
isnull = pd.DataFrame(df.isnull().sum(), columns=['isnull'])
isnull
# Out:
#                isnull
# Date                0
# Location            0
# MinTemp          1485
# MaxTemp          1261
# Rainfall         3261
# Evaporation     62790
# Sunshine        69835
# WindGustDir     10326
# WindGustSpeed   10263
# WindDir9am      10566
# WindDir3pm       4228
# WindSpeed9am     1767
# WindSpeed3pm     3062
# Humidity9am      2654
# Humidity3pm      4507
# Pressure9am     15065
# Pressure3pm     15028
# Cloud9am        55888
# Cloud3pm        59358
# Temp9am          1767
# Temp3pm          3609
# RainToday        3261
# RainTomorrow     3267

# %% [markdown]
# #### 7.	Find out the unique counts of the columns and save the result as a dataframe.

# %%
nunique = pd.DataFrame([df[i].nunique() for i in df.columns], index=df.columns, columns=['nunique'])
nunique
# Out:
#                nunique
# Date              3436
# Location            49
# MinTemp            389
# MaxTemp            505
# Rainfall           681
# Evaporation        358
# Sunshine           145
# WindGustDir         16
# WindGustSpeed       67
# WindDir9am          16
# WindDir3pm          16
# WindSpeed9am        43
# WindSpeed3pm        44
# Humidity9am        101
# Humidity3pm        101
# Pressure9am        546
# Pressure3pm        549
# Cloud9am            10
# Cloud3pm            10
# Temp9am            441
# Temp3pm            502
# RainToday            2
# RainTomorrow         2

# %% [markdown]
# #### 8.	Merge the dataframes you created in questions 4-5-6-7. Expected output: example result

# %%
pd.concat([dtypes, notnull, isnull, nunique], axis = 1).reset_index().rename({'index':'Columns'},axis=1)
# Out:
#           Columns   dtypes  notnull  isnull  nunique
# 0            Date   object   145460       0     3436
# 1        Location   object   145460       0       49
# 2         MinTemp  float64   143975    1485      389
# 3         MaxTemp  float64   144199    1261      505
# 4        Rainfall  float64   142199    3261      681
# 5     Evaporation  float64    82670   62790      358
# 6        Sunshine  float64    75625   69835      145
# 7     WindGustDir   object   135134   10326       16
# 8   WindGustSpeed  float64   135197   10263       67
# 9      WindDir9am   object   134894   10566       16
# 10     WindDir3pm   object   141232    4228       16
# 11   WindSpeed9am  float64   143693    1767       43
# 12   WindSpeed3pm  float64   142398    3062       44
# 13    Humidity9am  float64   142806    2654      101
# 14    Humidity3pm  float64   140953    4507      101
# 15    Pressure9am  float64   130395   15065      546
# 16    Pressure3pm  float64   130432   15028      549
# ...

# %% [markdown]
# #### 9.	Lowercase all column names.

# %%
df.columns=[i.lower() for i in df.columns]
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'humidity9am', 'humidity3pm',
#        'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am',
#        'temp3pm', 'raintoday', 'raintomorrow'],
#       dtype='object')

# %% [markdown]
# #### 10.	Change all the No values to NoRain and all the Yes values to Rain in raintoday and raintomorrow columns.

# %%
df = df.replace({'No':"NoRain",'Yes':'Rain'})

# %% [markdown]
# #### 11.	Change the data type of "date" (object) column to datetime64 and reformat the date as DD/MM/YYYY.

# %%
df.date = pd.to_datetime(df.date)

# %% [markdown]
# #### 12.	Create a new column called "difference", calculate the difference between maxtemp and mintemp columns for each row, and store the value in this new column.

# %%
df['difference']=df.maxtemp-df.mintemp
df.head()
# Out:
#         date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity3pm  pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  raintomorrow  \
# ...

# %% [markdown]
# #### 13.	Remove the evaporation and sunshine columns from the dataset permanently.

# %%
df2=df.copy()
df2.drop(['evaporation','sunshine'], axis=1, inplace=True)
df2.head()
# Out:
#         date location  mintemp  maxtemp  rainfall windgustdir  windgustspeed  \
# 0 2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1 2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2 2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3 2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4 2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   winddir9am winddir3pm  windspeed9am  ...  humidity3pm  pressure9am  \
# 0          W        WNW          20.0  ...         22.0       1007.7
# 1        NNW        WSW           4.0  ...         25.0       1010.6
# 2          W        WSW          19.0  ...         30.0       1007.6
# 3         SE          E          11.0  ...         16.0       1017.6
# 4        ENE         NW           7.0  ...         33.0       1010.8
#
#    pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  raintomorrow  \
# ...

# %% [markdown]
# #### 14.	Find out the most rainy day for each city.

# %%
df.loc[df.groupby('location')['rainfall'].idxmax().values][['location','date','rainfall']]
# Out:
#                 location       date  rainfall
# 98285           Adelaide 2014-02-14      75.2
# 109820            Albany 2012-06-02      49.4
# 1156              Albury 2012-03-01     104.2
# 136525      AliceSprings 2010-02-28      62.0
# 4468       BadgerysCreek 2013-01-29     116.0
# 55876           Ballarat 2011-01-14      95.0
# 58938            Bendigo 2011-02-05      66.4
# 86414           Brisbane 2015-05-02     182.6
# 87242             Cairns 2009-01-12     278.4
# 46715           Canberra 2010-12-03      87.0
# 7832               Cobar 2014-02-16      68.0
# 9368        CoffsHarbour 2009-11-07     371.0
# 81741           Dartmoor 2011-01-14      73.6
# 140071            Darwin 2011-02-16     367.6
# 91455          GoldCoast 2012-04-29     183.4
# 132137            Hobart 2015-01-14      71.6
# 143335         Katherine 2015-12-27     167.0
# 135557        Launceston 2016-01-29      88.0
# 68151          Melbourne 2011-02-07      82.2
# ...

# %% [markdown]
# #### 15.	Filter out all the data for the city 'Albury' and then sort according to maxtemp column.

# %%
df[df.location=='Albury'].sort_values('maxtemp', ascending=False)
# Out:
#            date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 68   2009-02-07   Albury     22.3     44.8       0.0          NaN       NaN
# 2904 2017-02-10   Albury     23.0     43.7       0.0          NaN       NaN
# 1783 2014-01-16   Albury     23.0     43.6       0.0          NaN       NaN
# 1435 2013-01-05   Albury     19.8     43.4       0.0          NaN       NaN
# 62   2009-02-01   Albury     28.0     43.1       0.0          NaN       NaN
# ...         ...      ...      ...      ...       ...          ...       ...
# 984  2011-09-11   Albury      NaN      NaN       NaN          NaN       NaN
# 985  2011-09-12   Albury      NaN      NaN       NaN          NaN       NaN
# 1529 2013-05-07   Albury      3.9      NaN       0.0          NaN       NaN
# 2031 2014-09-21   Albury      3.4      NaN       0.0          NaN       NaN
# 2032 2014-09-22   Albury      NaN      NaN       NaN          NaN       NaN
#
# ...

# %% [markdown]
# #### 16.	Find out the NaN counts for each column.

# %%
df.isnull().sum()
# Out:
# date                 0
# location             0
# mintemp           1485
# maxtemp           1261
# rainfall          3261
# evaporation      62790
# sunshine         69835
# windgustdir      10326
# windgustspeed    10263
# winddir9am       10566
# winddir3pm        4228
# windspeed9am      1767
# windspeed3pm      3062
# humidity9am       2654
# humidity3pm       4507
# pressure9am      15065
# pressure3pm      15028
# cloud9am         55888
# cloud3pm         59358
# temp9am           1767
# temp3pm           3609
# raintoday         3261
# raintomorrow      3267
# difference        1881
# dtype: int64

# %% [markdown]
# #### 17.	Remove the rows with NaN values in "windgustdir" column from the dataframe permanently.

# %%
df2=df.copy()
df2.dropna(subset=['windgustdir'], axis=0, inplace=True)

# %% [markdown]
# #### 18.	Create a new dataframe, use "Location" column as the index of the dataframe, display the min, max, and median values of "evaporation" and "sunshine" columns in this dataframe.

# %%
df.groupby('location')['evaporation','sunshine'].agg(['min','max','median'])
# Out:
#                  evaporation               sunshine
#                          min    max median      min   max median
# location
# Adelaide                 0.0   43.4    4.2      0.0  13.9   8.40
# Albany                   0.0   33.6    3.8      0.0  13.8   6.90
# Albury                   NaN    NaN    NaN      NaN   NaN    NaN
# AliceSprings             0.0   50.2    8.2      0.0  13.5  10.60
# BadgerysCreek            NaN    NaN    NaN      NaN   NaN    NaN
# Ballarat                 NaN    NaN    NaN      NaN   NaN    NaN
# Bendigo                  0.0   15.4    3.1      NaN   NaN    NaN
# Brisbane                 0.0   44.0    5.2      0.0  13.5   9.40
# Cairns                   0.2   44.4    6.0      0.0  12.8   8.60
# Canberra                 0.0   20.0    3.6      0.0  13.6   8.00
# Cobar                    0.0   86.2    5.6      0.0  13.7   9.90
# CoffsHarbour             0.0   19.8    3.6      0.0  13.8   8.50
# ...

# %%
# Alternatively
df3=pd.DataFrame()
df3['evaporation_min'] = df.groupby('location')['evaporation'].min()
df3['evaporation_max'] = df.groupby('location')['evaporation'].max()
df3['evaporation_median'] = df.groupby('location')['evaporation'].median()
df3['sunshine_min'] = df.groupby('location')['sunshine'].min()
df3['sunshine_max'] = df.groupby('location')['sunshine'].max()
df3['sunshine_median'] = df.groupby('location')['sunshine'].median()
df3
# Out:
#                   evaporation_min  evaporation_max  evaporation_median  \
# location
# Adelaide                      0.0             43.4                 4.2
# Albany                        0.0             33.6                 3.8
# Albury                        NaN              NaN                 NaN
# AliceSprings                  0.0             50.2                 8.2
# BadgerysCreek                 NaN              NaN                 NaN
# Ballarat                      NaN              NaN                 NaN
# Bendigo                       0.0             15.4                 3.1
# Brisbane                      0.0             44.0                 5.2
# Cairns                        0.2             44.4                 6.0
# Canberra                      0.0             20.0                 3.6
# Cobar                         0.0             86.2                 5.6
# CoffsHarbour                  0.0             19.8                 3.6
# ...

# %%
# Alternative
df3=pd.DataFrame()
df3['evaporation_min'] = df.groupby('location').apply(lambda x: min(x['evaporation']))
df3['evaporation_max'] = df.groupby('location').apply(lambda x: max(x['evaporation']))
df3['evaporation_median'] = df.groupby('location').apply(lambda x: x['evaporation'].median())
df3['sunshine_min'] = df.groupby('location').apply(lambda x: min(x['sunshine']))
df3['sunshine_max'] = df.groupby('location').apply(lambda x: max(x['sunshine']))
df3['sunshine_median'] = df.groupby('location').apply(lambda x: x['sunshine'].median())
df3
# Out:
#                   evaporation_min  evaporation_max  evaporation_median  \
# location
# Adelaide                      0.0             43.4                 4.2
# Albany                        0.0             33.6                 3.8
# Albury                        NaN              NaN                 NaN
# AliceSprings                  0.0             50.2                 8.2
# BadgerysCreek                 NaN              NaN                 NaN
# Ballarat                      NaN              NaN                 NaN
# Bendigo                       0.0             15.4                 3.1
# Brisbane                      0.0             44.0                 5.2
# Cairns                        0.2             44.4                 6.0
# Canberra                      0.0             20.0                 3.6
# Cobar                         0.0             86.2                 5.6
# CoffsHarbour                  0.0             19.8                 3.6
# ...

# %%
# Alternative
df_min = df.groupby('location')['evaporation','sunshine'].min()
df_max = df.groupby('location')['evaporation','sunshine'].max()
df_median = df.groupby('location')['evaporation','sunshine'].median()
df_min.merge(df_max, on='location',suffixes=('_min','_max')).merge(df_median, on='location').rename({'evaporation':'evaporation_median','sunshine':'sunshine_median'},axis=1)
# Out:
#                   evaporation_min  sunshine_min  evaporation_max  \
# location
# Adelaide                      0.0           0.0             43.4
# Albany                        0.0           0.0             33.6
# Albury                        NaN           NaN              NaN
# AliceSprings                  0.0           0.0             50.2
# BadgerysCreek                 NaN           NaN              NaN
# Ballarat                      NaN           NaN              NaN
# Bendigo                       0.0           NaN             15.4
# Brisbane                      0.0           0.0             44.0
# Cairns                        0.2           0.0             44.4
# Canberra                      0.0           0.0             20.0
# Cobar                         0.0           0.0             86.2
# CoffsHarbour                  0.0           0.0             19.8
# Dartmoor                      0.0           0.0             16.4
# ...

# %% [markdown]
# #### 19.	Find out the hottest day of "Perth". Example output: Timestamp('2015-01-05 00:00:00')

# %%
df[df.location=='Perth'][['location','date','maxtemp']][df.maxtemp == df[df.location=='Perth']['maxtemp'].max()]
# Out:
#        location       date  maxtemp
# 122928    Perth 2015-01-05     44.4

# %% [markdown]
# #### 20.	Group your dataframe by location and find out the averages of all numeric values.

# %%
df.groupby('location').mean()
# Out:
#                     mintemp    maxtemp  rainfall  evaporation  sunshine  \
# location
# Adelaide          12.579505  22.898934  1.566354     5.770364  7.747993
# Albany            12.948438  20.070998  2.263859     4.213345  6.657460
# Albury             9.530604  22.640872  1.914115          NaN       NaN
# AliceSprings      13.142284  29.248420  0.882850     9.026832  9.581944
# BadgerysCreek     11.131719  24.031208  2.193101          NaN       NaN
# Ballarat           7.367950  18.287266  1.740026          NaN       NaN
# Bendigo            8.593713  21.621746  1.619380     3.851730       NaN
# Brisbane          16.423807  26.448380  3.144891     5.407940  8.081170
# Cairns            21.220467  29.558849  5.742035     6.256891  7.571451
# Canberra           6.821866  20.976639  1.741720     4.399672  7.402038
# Cobar             13.149451  25.870093  1.127309     6.744861  8.674364
# CoffsHarbour      14.437108  23.965385  5.061497     3.905154  7.358367
# ...

# %% [markdown]
# ## Question-2
# Convert and merge json files into one Pandas.Dataframe

# %%
Json1 = [{'name': 'JOHN', 
          'age': 27}, 
         {'name': 'HENRY2', 
          'age': 14}]

Json2 = {1:{'name': 'vikash', 
             'age': 27}, 
         2:{'name': 'Satyam', 
            'age': 14} }

data = [{'id': 1, 
         'name': "Cole Volk", 
         'fitness': {'height': 130, 'weight': 60}}, 
        {'name': "Mose Reg",
         'fitness': {'height': 130, 'weight': 60}}, 
        {'id': 2, 
         'name': 'Faye Raker', 
         'fitness': {'height': 130, 'weight':60}}]

# %%
# Create df1 from Json1
df1=pd.DataFrame(Json1)
df1
# Out:
#      name  age
# 0    JOHN   27
# 1  HENRY2   14

# %%
# Create df2 from Json2
df2=pd.DataFrame(Json2).T
df2
# Out:
#      name age
# 1  vikash  27
# 2  Satyam  14

# %%
# Concatenate df1 and df2 data frame
df3 = pd.concat([df1, df2], sort=False)
df3
# Out:
#      name age
# 0    JOHN  27
# 1  HENRY2  14
# 1  vikash  27
# 2  Satyam  14

# %%
# Create df dataframe from data
df=pd.DataFrame(data)
df
# Out:
#     id        name                        fitness
# 0  1.0   Cole Volk  {'height': 130, 'weight': 60}
# 1  NaN    Mose Reg  {'height': 130, 'weight': 60}
# 2  2.0  Faye Raker  {'height': 130, 'weight': 60}

# %%
# Create df4 Dataframe from df.fitness
df4=pd.DataFrame([i for i in df.fitness])
df4
# Out:
#    height  weight
# 0     130      60
# 1     130      60
# 2     130      60

# %%
# Concatenate df and df4 data frame
df4 = pd.concat([df,df4],axis=1).drop('fitness',axis=1)
df4
# Out:
#     id        name  height  weight
# 0  1.0   Cole Volk     130      60
# 1  NaN    Mose Reg     130      60
# 2  2.0  Faye Raker     130      60

# %%
df3.merge(df4, on='name', how='outer')
# Out:
#          name  age   id  height  weight
# 0        JOHN   27  NaN     NaN     NaN
# 1      HENRY2   14  NaN     NaN     NaN
# 2      vikash   27  NaN     NaN     NaN
# 3      Satyam   14  NaN     NaN     NaN
# 4   Cole Volk  NaN  1.0   130.0    60.0
# 5    Mose Reg  NaN  NaN   130.0    60.0
# 6  Faye Raker  NaN  2.0   130.0    60.0

# %% [markdown]
# ## Question-4
# How can we convert a Series to DataFrame?

# %%
# Solution-1
s = pd.Series(["a", "b", "c"],    
name="vals")    
s.to_frame()
# Out:
#   vals
# 0    a
# 1    b
# 2    c

# %%
# Solution-2
s = pd.Series(["a", "b", "c"],    
name="vals")    
pd.DataFrame(s)
# Out:
#   vals
# 0    a
# 1    b
# 2    c

# %% [markdown]
# ## Question-5
# How to convert String to date?

# %%
from datetime import datetime    
    
# Define dates as the strings       
date_str1 = 'Wednesday, July 14, 2018'    
date_str2 = '14/7/17'    
date_str3 = '07-14-2017'    
    
# Define dates as the datetime objects    
dmy_dt1 = datetime.strptime(date_str1, '%A, %B %d, %Y')    
dmy_dt2 = datetime.strptime(date_str2, '%d/%m/%y')    
dmy_dt3 = datetime.strptime(date_str3, '%m-%d-%Y')    
    
#Print the converted dates    
print(dmy_dt1, dmy_dt2, dmy_dt3) 

type(dmy_dt1), type(dmy_dt2), type(dmy_dt3)
# Out:
# 2018-07-14 00:00:00 2017-07-14 00:00:00 2017-07-14 00:00:00
# (datetime.datetime, datetime.datetime, datetime.datetime)
